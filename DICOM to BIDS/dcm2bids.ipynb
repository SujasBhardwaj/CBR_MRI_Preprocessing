# %%
import os
import shutil
import subprocess
from pathlib import Path
import re
import csv
import pydicom


incoming_dir = Path("incoming_dicoms")
processed_dir = Path("processed_dicoms")
bids_output_dir = Path("bids_output")
config_file = Path("dcm2bids.config.json")
subject_map_csv = Path("bids_output/subject_map.csv")  # CSV file to track subject info


processed_dir.mkdir(parents=True, exist_ok=True)


# === Get the next BIDS subject number ===
def get_next_subject_number(bids_dir):
    existing = [d.name for d in bids_dir.glob("sub-*")]
    numbers = [int(re.findall(r'\d+', name)[0]) for name in existing if re.match(r"sub-\d+", name)]
    return max(numbers, default=0) + 1


# === Extract age, sex, and scan date from DICOM headers ===
def extract_dicom_metadata(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(".dcm"):
                try:
                    dcm = pydicom.dcmread(os.path.join(root, file), stop_before_pixels=True)
                    age = getattr(dcm, "PatientAge", "NA")
                    sex = getattr(dcm, "PatientSex", "NA")
                    date = getattr(dcm, "StudyDate", "NA")
                    return age, sex, date
                except Exception:
                    continue
    return "NA", "NA", "NA"


# === Update CSV mapping of subject info ===
def update_subject_map(csv_file, patient_folder_name, subject_label, age, sex, scan_date):
    rows = []

    if csv_file.exists():
        with open(csv_file, "r", newline="") as f:
            reader = csv.reader(f)
            rows = list(reader)

        # Skip if already logged
        for row in rows:
            if row[0] == patient_folder_name:
                return

    with open(csv_file, "a", newline="") as f:
        writer = csv.writer(f)
        if not rows:
            writer.writerow(["OriginalFolder", "BIDS_Subject", "Age", "Sex", "ScanDate"])
        writer.writerow([patient_folder_name, f"sub-{subject_label}", age, sex, scan_date])


# === Process all unprocessed folders ===
for patient_folder in incoming_dir.iterdir():
    if not patient_folder.is_dir():
        continue

    # Skip if already marked as converted
    if (patient_folder / "converted.flag").exists():
        continue

    # Determine next subject label
    sub_num = get_next_subject_number(bids_output_dir)
    sub_label = f"{sub_num:06d}"

    print(f"\nProcessing folder: {patient_folder.name} → sub-{sub_label}")

    # Extract DICOM metadata
    age, sex, scan_date = extract_dicom_metadata(patient_folder)

    # Construct dcm2bids command
    cmd = [
        "dcm2bids",
        "-d", str(patient_folder),
        "-p", sub_label,
        "-c", str(config_file),
        "-o", str(bids_output_dir),
        "--force_dcm2bids",
        "--clobber",
        "-l", "DEBUG"
    ]

    try:
        subprocess.run(cmd, check=True)

        # Mark as processed
        (patient_folder / "converted.flag").touch()

        # Update CSV
        update_subject_map(subject_map_csv, patient_folder.name, sub_label, age, sex, scan_date)

        # Move folder to processed_dir
        dest_folder = processed_dir / patient_folder.name
        if dest_folder.exists():
            print(f"Destination {dest_folder} already exists. Skipping move.")
        else:
            shutil.move(str(patient_folder), str(dest_folder))
            print(f"Moved {patient_folder.name} to processed folder.")

    except subprocess.CalledProcessError:
        print(f"Error processing {patient_folder.name}. Skipping.")
# Out:
# Processing folder: 865SK_B → sub-000001
# INFO    | --- dcm2bids start ---
# INFO    | Running the following command: /opt/miniconda3/envs/bidsenv/bin/dcm2bids -d incoming_dicoms/865SK_B -p 000001 -c dcm2bids.config.json -o bids_output --force_dcm2bids --clobber -l DEBUG
# INFO    | OS version: macOS-15.6-arm64-arm-64bit
# INFO    | Python version: 3.10.18 (main, Jun  5 2025, 08:37:47) [Clang 14.0.6 ]
# INFO    | dcm2bids version: 3.2.0
# INFO    | dcm2niix version: v1.0.20240202
# INFO    | Checking for software update
# INFO    | Currently using the latest version of dcm2bids.
# WARNING | A newer version exists for dcm2niix: v1.0.20250506
# WARNING | You should update it -> https://github.com/rordenlab/dcm2niix.
# INFO    | participant: sub-000001
# INFO    | config: /Users/PHARAOH/Downloads/Processing/dcm2bids.config.json
# INFO    | BIDS directory: /Users/PHARAOH/Downloads/Processing/bids_output
# INFO    | Auto extract entities: False
# INFO    | Reorder entities: True
# INFO    | Validate BIDS: False
#
# INFO    | Running: dcm2niix -b y -ba y -z y -f %3s_%f_%p_%t -o bids_output/tmp_dcm2bids/sub-000001 incoming_dicoms/865SK_B
# INFO    | Log from dcm2niix execution
# WARNING | Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20240202  Clang16.0.6 ARM (64-bit MacOS)
# Found 2156 DICOM file(s)
# Warning: interpolated protocol 'ep2d_diff_4scan_trace_p2_s2_2mm' may be unsuitable for dwidenoise/mrdegibbs. incoming_dicoms/865SK_B/ep2d_diff_4scan_trace_p2_s2_2mm_TRACEW_Series0020/Image (0001)
# Warning: interpolated protocol 'ep2d_diff_4scan_trace_p2_s2_2mm' may be unsuitable for dwidenoise/mrdegibbs. incoming_dicoms/865SK_B/ep2d_diff_4scan_trace_p2_s2_2mm_ADC_Series0019/Image (0001)
# Warning: interpolated protocol 'ep2d_diff_4scan_trace_p2_s2_2mm' may be unsuitable for dwidenoise/mrdegibbs. incoming_dicoms/865SK_B/ep2d_diff_4scan_trace_p2_s2_2mm_Series0018/Image (0001)
# Warning: interpolated protocol 'ep2d_diff_4scan_trace_p2_s2_2mm' may be unsuitable for dwidenoise/mrdegibbs. incoming_dicoms/865SK_B/ep2d_diff_4scan_trace_p2_s2_2mm_FA_Series0021/Image (0001)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000001/015_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031 (128x128x28x1)
# Slices not stacked: orientation varies (vNav or localizer?) [0.998996 -0.0107554 0.0434792 0.0134768 0.997936 -0.0627907] != [0.999176 0.0108375 0.0391224 -0.0185061 0.979345 0.201349]
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/004_865SK_B_Localizer_20220310155031_i00002 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/004_865SK_B_Localizer_20220310155031_i00001 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/004_865SK_B_Localizer_20220310155031_i00003 (162x162x1x1)
# Convert 176 DICOM as bids_output/tmp_dcm2bids/sub-000001/005_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_20220310155031 (240x256x176x1)
# Convert 150 DICOM as bids_output/tmp_dcm2bids/sub-000001/010_865SK_B_t2_FLAIR_3D_sag_p2_iso_MPR_tra_20220310155031 (256x256x150x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/027_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (16x16x1x1)
# Convert 42 DICOM as bids_output/tmp_dcm2bids/sub-000001/012_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031 (128x128x28x42)
# Warning: Instance Number (0020,0013) order is not spatial.
# Unable to determine spatial orientation: 0020,0037 missing (probably not a problem: derived image)
# Warning: Unable to determine slice direction: please check whether slices are flipped (derived image)
# Warning: Bogus spatial matrix (perhaps non-spatial image): inspect spatial orientation
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000001/016_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031 (128x128x28x1)
# Convert 3 DICOM as bids_output/tmp_dcm2bids/sub-000001/031_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (64x64x45x3)
# Convert 30 DICOM as bids_output/tmp_dcm2bids/sub-000001/024_865SK_B_t2_tse_HRH_tra_448_2mm_20220310155031 (448x448x30x1)
# Convert 176 DICOM as bids_output/tmp_dcm2bids/sub-000001/008_865SK_B_t2_FLAIR_3D_sag_p2_iso_20220310155031 (256x256x176x1)
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000001/019_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031 (208x208x45x1)
# Convert 180 DICOM as bids_output/tmp_dcm2bids/sub-000001/009_865SK_B_t2_FLAIR_3D_sag_p2_iso_MPR_cor_20220310155031 (256x256x180x1)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000001/014_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031 (128x128x28x1)
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000001/020_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031 (208x208x45x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/003_865SK_B_Localizer_20220310155031_i00001 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/003_865SK_B_Localizer_20220310155031_i00002 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/003_865SK_B_Localizer_20220310155031_i00003 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/029_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (180x179x1x1)
# Convert 128 DICOM as bids_output/tmp_dcm2bids/sub-000001/001_865SK_B_Localizer_20220310155031 (160x160x128x1)
# ::autoBids:Siemens CSAseqFname:'%SiemensSeq%\medic' pulseSeq:'' seqName:'*me3d1r3'
# Convert 176 DICOM as bids_output/tmp_dcm2bids/sub-000001/011_865SK_B_t2_fl3d_sag_T2_star_iso_20220310155031 (240x256x176x1)
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000001/025_865SK_B_gre_field_mapping_NPR-1_20220310155031_e2_ph (128x128x45x1)
# Convert 184 DICOM as bids_output/tmp_dcm2bids/sub-000001/026_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (64x64x45x184)
# Convert 150 DICOM as bids_output/tmp_dcm2bids/sub-000001/007_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_MPR_tra_20220310155031 (256x256x150x1)
# Convert 66 DICOM as bids_output/tmp_dcm2bids/sub-000001/018_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031 (208x208x45x66)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/030_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (64x64x45x1)
# Convert 2 DICOM as bids_output/tmp_dcm2bids/sub-000001/002_865SK_B_Localizer_20220310155031_i00001 (162x162x2x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/002_865SK_B_Localizer_20220310155031_i00003 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/002_865SK_B_Localizer_20220310155031_i00002 (162x162x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000001/002_865SK_B_Localizer_20220310155031_i00004 (162x162x1x1)
# Warning: Instance Number (0020,0013) order is not spatial.
# Unable to determine spatial orientation: 0020,0037 missing (probably not a problem: derived image)
# Warning: Unable to determine slice direction: please check whether slices are flipped (derived image)
# Warning: Bogus spatial matrix (perhaps non-spatial image): inspect spatial orientation
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000001/022_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031 (208x208x45x1)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000001/013_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031 (128x128x28x1)
# Convert 154 DICOM as bids_output/tmp_dcm2bids/sub-000001/028_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031 (64x64x45x154)
# Convert 180 DICOM as bids_output/tmp_dcm2bids/sub-000001/006_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_MPR_cor_20220310155031 (256x256x180x1)
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000001/021_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031 (208x208x45x1)
# Conversion required 37.221106 seconds (37.017422 for core code).
#
# INFO    | SIDECAR PAIRING
# INFO    | No Pairing  <-  001_865SK_B_Localizer_20220310155031
# INFO    | No Pairing  <-  002_865SK_B_Localizer_20220310155031_i00001
# INFO    | No Pairing  <-  002_865SK_B_Localizer_20220310155031_i00002
# INFO    | No Pairing  <-  002_865SK_B_Localizer_20220310155031_i00003
# INFO    | No Pairing  <-  002_865SK_B_Localizer_20220310155031_i00004
# INFO    | No Pairing  <-  003_865SK_B_Localizer_20220310155031_i00001
# INFO    | No Pairing  <-  003_865SK_B_Localizer_20220310155031_i00002
# INFO    | No Pairing  <-  003_865SK_B_Localizer_20220310155031_i00003
# INFO    | No Pairing  <-  004_865SK_B_Localizer_20220310155031_i00001
# INFO    | No Pairing  <-  004_865SK_B_Localizer_20220310155031_i00002
# INFO    | No Pairing  <-  004_865SK_B_Localizer_20220310155031_i00003
# INFO    | sub-000001_T1w  <-  005_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_20220310155031
# INFO    | No Pairing  <-  006_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_MPR_cor_20220310155031
# INFO    | No Pairing  <-  007_865SK_B_t1_mprage_sag_p2_iso_TA_5.03_MPR_tra_20220310155031
# INFO    | sub-000001_FLAIR  <-  008_865SK_B_t2_FLAIR_3D_sag_p2_iso_20220310155031
# INFO    | No Pairing  <-  009_865SK_B_t2_FLAIR_3D_sag_p2_iso_MPR_cor_20220310155031
# INFO    | No Pairing  <-  010_865SK_B_t2_FLAIR_3D_sag_p2_iso_MPR_tra_20220310155031
# INFO    | sub-000001_T2starw  <-  011_865SK_B_t2_fl3d_sag_T2_star_iso_20220310155031
# INFO    | sub-000001_dwi  <-  012_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031
# INFO    | No Pairing  <-  013_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031
# INFO    | No Pairing  <-  014_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031
# INFO    | No Pairing  <-  015_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031
# INFO    | No Pairing  <-  016_865SK_B_ep2d_diff_mddw_20_p2(DTI)_20220310155031
# INFO    | sub-000001_dwi  <-  018_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031
# INFO    | No Pairing  <-  019_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031
# INFO    | No Pairing  <-  020_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031
# INFO    | No Pairing  <-  021_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031
# INFO    | No Pairing  <-  022_865SK_B_ep2d_diff_4scan_trace_p2_s2_2mm_20220310155031
# INFO    | sub-000001_T2w  <-  024_865SK_B_t2_tse_HRH_tra_448_2mm_20220310155031
# INFO    | No Pairing  <-  025_865SK_B_gre_field_mapping_NPR-1_20220310155031_e2_ph
# INFO    | sub-000001_task-rest_bold  <-  026_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | No Pairing  <-  027_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | No Pairing  <-  029_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | No Pairing  <-  030_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | No Pairing  <-  031_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | No Pairing  <-  028_865SK_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20220310155031
# INFO    | sub-000001/dwi/sub-000001_dwi has 2 runs
# INFO    | Adding run information to the acquisition
# INFO    | Moving acquisitions into BIDS folder "bids_output/sub-000001".
#
# INFO    | Logs saved in bids_output/tmp_dcm2bids/log/sub-000001_20250803-171510.log
# INFO    | --- dcm2bids end ---
# Moved 865SK_B to processed folder.
#
# Processing folder: 574NS_B → sub-000002
# INFO    | --- dcm2bids start ---
# INFO    | Running the following command: /opt/miniconda3/envs/bidsenv/bin/dcm2bids -d incoming_dicoms/574NS_B -p 000002 -c dcm2bids.config.json -o bids_output --force_dcm2bids --clobber -l DEBUG
# INFO    | OS version: macOS-15.6-arm64-arm-64bit
# INFO    | Python version: 3.10.18 (main, Jun  5 2025, 08:37:47) [Clang 14.0.6 ]
# INFO    | dcm2bids version: 3.2.0
# INFO    | dcm2niix version: v1.0.20240202
# INFO    | Checking for software update
# INFO    | Currently using the latest version of dcm2bids.
# WARNING | A newer version exists for dcm2niix: v1.0.20250506
# WARNING | You should update it -> https://github.com/rordenlab/dcm2niix.
# INFO    | participant: sub-000002
# INFO    | config: /Users/PHARAOH/Downloads/Processing/dcm2bids.config.json
# INFO    | BIDS directory: /Users/PHARAOH/Downloads/Processing/bids_output
# INFO    | Auto extract entities: False
# INFO    | Reorder entities: True
# INFO    | Validate BIDS: False
#
# INFO    | Running: dcm2niix -b y -ba y -z y -f %3s_%f_%p_%t -o bids_output/tmp_dcm2bids/sub-000002 incoming_dicoms/574NS_B
# INFO    | Log from dcm2niix execution
# WARNING | Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20240202  Clang16.0.6 ARM (64-bit MacOS)
# Found 1481 DICOM file(s)
# Warning: interpolated protocol 't2_FLAIR_3D_sag_p2_iso' may be unsuitable for dwidenoise/mrdegibbs. incoming_dicoms/574NS_B/t2_FLAIR_3D_sag_p2_iso_Series0004/Image (0001)
# Convert 176 DICOM as bids_output/tmp_dcm2bids/sub-000002/003_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212 (240x256x176x1)
# Slices not stacked: dimensions vary across slices
# Convert 175 DICOM as bids_output/tmp_dcm2bids/sub-000002/100_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212 (256x256x175x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/100_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212a (484x484x1x1)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000002/007_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212 (128x128x28x1)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000002/006_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212 (128x128x28x1)
# Convert 152 DICOM as bids_output/tmp_dcm2bids/sub-000002/101_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212 (256x256x152x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/101_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212a (484x484x1x1)
# Convert 176 DICOM as bids_output/tmp_dcm2bids/sub-000002/004_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212 (512x512x176x1)
# Warning: Instance Number (0020,0013) order is not spatial.
# Unable to determine spatial orientation: 0020,0037 missing (probably not a problem: derived image)
# Warning: Unable to determine slice direction: please check whether slices are flipped (derived image)
# Warning: Bogus spatial matrix (perhaps non-spatial image): inspect spatial orientation
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000002/009_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212 (128x128x28x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/034_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212 (180x179x1x1)
# Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/035_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212 (64x64x45x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/002_574NS_B_localizer_20200309105212_i00002 (192x192x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/002_574NS_B_localizer_20200309105212_i00003 (192x192x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/002_574NS_B_localizer_20200309105212_i00001 (192x192x1x1)
# Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# Convert 3 DICOM as bids_output/tmp_dcm2bids/sub-000002/036_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212 (64x64x45x3)
# ::autoBids:Siemens CSAseqFname:'*spcir_278ns' pulseSeq:'' seqName:'*spcir_278ns'
# Convert 153 DICOM as bids_output/tmp_dcm2bids/sub-000002/103_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212 (512x512x153x1)
# ::autoBids:Siemens CSAseqFname:'*spcir_278ns' pulseSeq:'' seqName:'*spcir_278ns'
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/103_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212a (484x484x1x1)
# Convert 28 DICOM as bids_output/tmp_dcm2bids/sub-000002/008_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212 (128x128x28x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/012_574NS_B_tgse_pcasl_5delay_2.5x2.5x3_20200309105212 (96x96x42x1)
# Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# Convert 184 DICOM as bids_output/tmp_dcm2bids/sub-000002/033_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212 (64x64x45x184)
# Convert 30 DICOM as bids_output/tmp_dcm2bids/sub-000002/013_574NS_B_t2_tse_HRH_tra_448_2mm_20200309105212 (448x448x30x1)
# Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# Convert 42 DICOM as bids_output/tmp_dcm2bids/sub-000002/005_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212 (128x128x28x42)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/001_574NS_B_localizer_20200309105212_i00002 (192x192x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/001_574NS_B_localizer_20200309105212_i00003 (192x192x1x1)
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/001_574NS_B_localizer_20200309105212_i00001 (192x192x1x1)
# Convert 45 DICOM as bids_output/tmp_dcm2bids/sub-000002/032_574NS_B_gre_field_mapping_NPR-1_20200309105212_e2_ph (128x128x45x1)
# ::autoBids:Siemens CSAseqFname:'*spcir_278ns' pulseSeq:'' seqName:'*spcir_278ns'
# Convert 175 DICOM as bids_output/tmp_dcm2bids/sub-000002/102_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212 (512x512x175x1)
# ::autoBids:Siemens CSAseqFname:'*spcir_278ns' pulseSeq:'' seqName:'*spcir_278ns'
# Convert 1 DICOM as bids_output/tmp_dcm2bids/sub-000002/102_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212a (484x484x1x1)
# Convert 26 DICOM as bids_output/tmp_dcm2bids/sub-000002/011_574NS_B_tgse_pcasl_5delay_2.5x2.5x3_20200309105212 (96x96x42x26)
# Conversion required 28.561383 seconds (28.504623 for core code).
#
# INFO    | SIDECAR PAIRING
# INFO    | No Pairing  <-  001_574NS_B_localizer_20200309105212_i00001
# INFO    | No Pairing  <-  001_574NS_B_localizer_20200309105212_i00002
# INFO    | No Pairing  <-  001_574NS_B_localizer_20200309105212_i00003
# INFO    | No Pairing  <-  002_574NS_B_localizer_20200309105212_i00002
# INFO    | No Pairing  <-  002_574NS_B_localizer_20200309105212_i00003
# INFO    | No Pairing  <-  002_574NS_B_localizer_20200309105212_i00001
# INFO    | sub-000002_T1w  <-  003_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212
# INFO    | No Pairing  <-  100_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212
# INFO    | No Pairing  <-  100_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212a
# INFO    | No Pairing  <-  101_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212
# INFO    | No Pairing  <-  101_574NS_B_t1_mprage_sag_p2_iso_TA_5.03_20200309105212a
# INFO    | sub-000002_FLAIR  <-  004_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212
# INFO    | No Pairing  <-  102_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212
# INFO    | No Pairing  <-  102_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212a
# INFO    | No Pairing  <-  103_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212
# INFO    | No Pairing  <-  103_574NS_B_t2_FLAIR_3D_sag_p2_iso_20200309105212a
# INFO    | sub-000002_dwi  <-  005_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212
# INFO    | No Pairing  <-  006_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212
# INFO    | No Pairing  <-  007_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212
# INFO    | No Pairing  <-  008_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212
# INFO    | No Pairing  <-  009_574NS_B_ep2d_diff_mddw_20_p2(DTI)_20200309105212
# INFO    | No Pairing  <-  011_574NS_B_tgse_pcasl_5delay_2.5x2.5x3_20200309105212
# INFO    | No Pairing  <-  012_574NS_B_tgse_pcasl_5delay_2.5x2.5x3_20200309105212
# INFO    | sub-000002_T2w  <-  013_574NS_B_t2_tse_HRH_tra_448_2mm_20200309105212
# INFO    | No Pairing  <-  032_574NS_B_gre_field_mapping_NPR-1_20200309105212_e2_ph
# INFO    | sub-000002_task-rest_bold  <-  033_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212
# INFO    | No Pairing  <-  034_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212
# INFO    | No Pairing  <-  035_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212
# INFO    | No Pairing  <-  036_574NS_B_ep2d_bold_moco_RESTING_NPR-22-11-15_20200309105212
# INFO    | Moving acquisitions into BIDS folder "bids_output/sub-000002".
#
# INFO    | Logs saved in bids_output/tmp_dcm2bids/log/sub-000002_20250803-171548.log
# INFO    | --- dcm2bids end ---
# Moved 574NS_B to processed folder.
